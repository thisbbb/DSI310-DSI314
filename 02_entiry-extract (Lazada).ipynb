# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 29.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 1.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 31.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 35.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 33.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 31.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.7 MB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 85
dir_process_id = 86

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY5MTIzMjkxLCJpYXQiOjE2NjkwMzY4OTEsImp0aSI6IjIxNTIyNjA3ZjA3YzQ0Y2Q4YzQzZTZmNjY4NmUzZTU2IiwidXNlcl9pZCI6MzN9.nvUwAIzfOiovJRFBCwKI-9jO7Lmjgh2sSajJEZxB7Ac"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='plantbasedfood_lazada.csv'))
meta
# Out:
# {'owner': 'thanaporn',
#  'human_size': '512.85 KB',
#  'name': 'plantbasedfood_lazada.csv',
#  'description': 'file plantbasedfood_lazada.csv',
#  'directory': 85,
#  'path': 'thanaporn/DSI310-G3/rawData/plantbasedfood_lazada.csv'}

# %%
data = pd.read_csv('./plantbasedfood_lazada.csv')
data
# Out:
#                                             NameProduct      Price no_Review  \
# 0      Plant​Based food โปรตีนถั่วเหลือง เบอร์4 ฟู๊ดเทค    ฿124.00       (5)
# 1     [Plant Based protein] ALL PRO Pea Protein Isol...  ฿3,720.00       (7)
# 2                  KAY KAY Organic Plant Protein Greens  ฿1,090.00     (906)
# 3     ปลาหมึกหยองเจ Yota โยตา อาหารเจ ผลิตจากเมล็ดถั...     ฿50.00      (66)
# 4     HEALTHY CHOICE เมล็ดควินัว 3 สี ออร์แกนิค Orga...    ฿283.00     (723)
# ...                                                 ...        ...       ...
# 1955  MFL™ VEGAN PLANT BASED PROTEIN 2.12lbs - Choco...  ฿1,669.00      (82)
# 1956  ปูพันสาหร่ายเจ โยตา อาหารเจ Vegan Nuggets   เน...    ฿118.00       (1)
# 1957  🥩หมูแดงเจ Youta (โยตา) แพ็คใหญ่ ขนาด 1 กิโลกรั...    ฿187.00       (7)
# 1958  🍄ขาเห็ดหอมปรุงรสเจ (เนื้อแพะขาเห็ดเจ) Youta (โ...    ฿124.00     (330)
# 1959           HEALTHYCHOICEควินัว2 สี ออร์แกนิค 1000 g    ฿264.00      (67)
#
#           Location
# 0       Phetchabun
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                             NameProduct      Price no_Review  \
# 0      Plant​Based food โปรตีนถั่วเหลือง เบอร์4 ฟู๊ดเทค    ฿124.00       (5)
# 1     [Plant Based protein] ALL PRO Pea Protein Isol...  ฿3,720.00       (7)
# 2                  KAY KAY Organic Plant Protein Greens  ฿1,090.00     (906)
# 3     ปลาหมึกหยองเจ Yota โยตา อาหารเจ ผลิตจากเมล็ดถั...     ฿50.00      (66)
# 4     HEALTHY CHOICE เมล็ดควินัว 3 สี ออร์แกนิค Orga...    ฿283.00     (723)
# ...                                                 ...        ...       ...
# 1955  MFL™ VEGAN PLANT BASED PROTEIN 2.12lbs - Choco...  ฿1,669.00      (82)
# 1956  ปูพันสาหร่ายเจ โยตา อาหารเจ Vegan Nuggets   เน...    ฿118.00       (1)
# 1957  🥩หมูแดงเจ Youta (โยตา) แพ็คใหญ่ ขนาด 1 กิโลกรั...    ฿187.00       (7)
# 1958  🍄ขาเห็ดหอมปรุงรสเจ (เนื้อแพะขาเห็ดเจ) Youta (โ...    ฿124.00     (330)
# 1959           HEALTHYCHOICEควินัว2 สี ออร์แกนิค 1000 g    ฿264.00      (67)
#
#           Location
# 0       Phetchabun
# ...

# %%
df = df.rename(columns = {'NameProduct' : 'Product_name'})
df = df.rename(columns = {'no_Review' : 'Review_count'})
df
# Out:
#                                            Product_name      Price  \
# 0      Plant​Based food โปรตีนถั่วเหลือง เบอร์4 ฟู๊ดเทค    ฿124.00
# 1     [Plant Based protein] ALL PRO Pea Protein Isol...  ฿3,720.00
# 2                  KAY KAY Organic Plant Protein Greens  ฿1,090.00
# 3     ปลาหมึกหยองเจ Yota โยตา อาหารเจ ผลิตจากเมล็ดถั...     ฿50.00
# 4     HEALTHY CHOICE เมล็ดควินัว 3 สี ออร์แกนิค Orga...    ฿283.00
# ...                                                 ...        ...
# 1955  MFL™ VEGAN PLANT BASED PROTEIN 2.12lbs - Choco...  ฿1,669.00
# 1956  ปูพันสาหร่ายเจ โยตา อาหารเจ Vegan Nuggets   เน...    ฿118.00
# 1957  🥩หมูแดงเจ Youta (โยตา) แพ็คใหญ่ ขนาด 1 กิโลกรั...    ฿187.00
# 1958  🍄ขาเห็ดหอมปรุงรสเจ (เนื้อแพะขาเห็ดเจ) Youta (โ...    ฿124.00
# 1959           HEALTHYCHOICEควินัว2 สี ออร์แกนิค 1000 g    ฿264.00
#
#      Review_count      Location
# 0             (5)    Phetchabun
# 1             (7)       Bangkok
# 2           (906)  Samut Prakan
# ...

# %%
df['Price'] = df['Price'].str.replace("฿", "")
df
# Out:
#                                            Product_name     Price  \
# 0      Plant​Based food โปรตีนถั่วเหลือง เบอร์4 ฟู๊ดเทค    124.00
# 1     [Plant Based protein] ALL PRO Pea Protein Isol...  3,720.00
# 2                  KAY KAY Organic Plant Protein Greens  1,090.00
# 3     ปลาหมึกหยองเจ Yota โยตา อาหารเจ ผลิตจากเมล็ดถั...     50.00
# 4     HEALTHY CHOICE เมล็ดควินัว 3 สี ออร์แกนิค Orga...    283.00
# ...                                                 ...       ...
# 1955  MFL™ VEGAN PLANT BASED PROTEIN 2.12lbs - Choco...  1,669.00
# 1956  ปูพันสาหร่ายเจ โยตา อาหารเจ Vegan Nuggets   เน...    118.00
# 1957  🥩หมูแดงเจ Youta (โยตา) แพ็คใหญ่ ขนาด 1 กิโลกรั...    187.00
# 1958  🍄ขาเห็ดหอมปรุงรสเจ (เนื้อแพะขาเห็ดเจ) Youta (โ...    124.00
# 1959           HEALTHYCHOICEควินัว2 สี ออร์แกนิค 1000 g    264.00
#
#      Review_count      Location
# 0             (5)    Phetchabun
# 1             (7)       Bangkok
# 2           (906)  Samut Prakan
# 3            (66)       Bangkok
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="Lazada", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='plantbasedfood_lazada.csv')])
# Out:
# {'sucess': True,
#  'file_id': 904,
#  'path': 'thanaporn/DSI310-G3/processData/Lazada.parquet',
#  'lineage': True}
