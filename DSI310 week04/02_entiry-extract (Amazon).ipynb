# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 28.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 1.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 27.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 36.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 30.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 1.9 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 18.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.1 MB/s eta 0:00:0000:01
# ...

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 85
dir_process_id = 86

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY4Njc4NDYxLCJpYXQiOjE2Njg1OTIwNjAsImp0aSI6ImVlZmEzY2EzZmE4MTQzZDQ4ZjBiZjkwZjNiMmY0MmE4IiwidXNlcl9pZCI6MzN9.DSQPn4-OzVYWZ7cLADAQ459eqnv-Au1DezbutAZO2LM"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='Amazon(1).csv'))
meta
# Out:
# {'owner': 'thanaporn',
#  'human_size': '7.80 KB',
#  'name': 'Amazon(1).csv',
#  'description': 'file Amazon(1).csv',
#  'directory': 85,
#  'path': 'thanaporn/DSI310-G3/rawData/Amazon(1).csv'}

# %%
data = pd.read_csv('./Amazon(1).csv')
data
# Out:
#     Unnamed: 0                                               Name  \
# 0            0  ilumot 100% Plant-Based | PREMIUM Compostable ...
# 1            1  Orgain Organic Kids Vegan Protein Nutritional ...
# 2            2  CLIF BARS - Energy Bars - Chocolate Chip - Mad...
# 3            3  CLIF BARS - Energy Bars - Best Sellers Variety...
# 4            4         Halo Vegan Adult Dry Dog Food, Plant-Based
# 5            5  Larabar Peanut Butter Cookie, Gluten Free Vega...
# 6            6  Orgain Organic Plant Based Protein Bar, Peanut...
# 7            7  Orgain Organic Vegan Plant Based Nutritional S...
# 8            8  Vana Life's Foods Plant based Ready Meal - Gre...
# 9            9  Wellness CORE Bowl Boosters, Functional Meal T...
# 10          10  Plant Based Cookbook For Beginners: 1000 Days ...
# 11          11  Wellness CORE Digestive Health Dry Dog Food wi...
# 12          12  Vega Protein and Greens, Chocolate, Vegan Prot...
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#     Unnamed: 0                                               Name  \
# 0            0  ilumot 100% Plant-Based | PREMIUM Compostable ...
# 1            1  Orgain Organic Kids Vegan Protein Nutritional ...
# 2            2  CLIF BARS - Energy Bars - Chocolate Chip - Mad...
# 3            3  CLIF BARS - Energy Bars - Best Sellers Variety...
# 4            4         Halo Vegan Adult Dry Dog Food, Plant-Based
# 5            5  Larabar Peanut Butter Cookie, Gluten Free Vega...
# 6            6  Orgain Organic Plant Based Protein Bar, Peanut...
# 7            7  Orgain Organic Vegan Plant Based Nutritional S...
# 8            8  Vana Life's Foods Plant based Ready Meal - Gre...
# 9            9  Wellness CORE Bowl Boosters, Functional Meal T...
# 10          10  Plant Based Cookbook For Beginners: 1000 Days ...
# 11          11  Wellness CORE Digestive Health Dry Dog Food wi...
# 12          12  Vega Protein and Greens, Chocolate, Vegan Prot...
# ...

# %%
df['Rating'] = df['Rating'].str.replace("out of 5 stars", "")
df['Rating'] = df['Rating'].str.replace("Stars & Up", "")
df['Rating'] = df['Rating'].str.replace("Star & Up", "")
df
# Out:
#     Unnamed: 0                                               Name Rating  \
# 0            0  ilumot 100% Plant-Based | PREMIUM Compostable ...      -
# 1            1  Orgain Organic Kids Vegan Protein Nutritional ...   4.5
# 2            2  CLIF BARS - Energy Bars - Chocolate Chip - Mad...   4.6
# 3            3  CLIF BARS - Energy Bars - Best Sellers Variety...   4.7
# 4            4         Halo Vegan Adult Dry Dog Food, Plant-Based   4.5
# 5            5  Larabar Peanut Butter Cookie, Gluten Free Vega...   4.5
# 6            6  Orgain Organic Plant Based Protein Bar, Peanut...   4.2
# 7            7  Orgain Organic Vegan Plant Based Nutritional S...   4.4
# 8            8  Vana Life's Foods Plant based Ready Meal - Gre...   4.6
# 9            9  Wellness CORE Bowl Boosters, Functional Meal T...   4.5
# 10          10  Plant Based Cookbook For Beginners: 1000 Days ...   4.4
# 11          11  Wellness CORE Digestive Health Dry Dog Food wi...   4.5
# ...

# %%
df = df.drop(columns = {'Unnamed: 0'})
df
# Out:
#                                                  Name Rating Review  Price
# 0   ilumot 100% Plant-Based | PREMIUM Compostable ...      -      -  12.50
# 1   Orgain Organic Kids Vegan Protein Nutritional ...   4.5    1158      -
# 2   CLIF BARS - Energy Bars - Chocolate Chip - Mad...   4.6     364      -
# 3   CLIF BARS - Energy Bars - Best Sellers Variety...   4.7   20137      -
# 4          Halo Vegan Adult Dry Dog Food, Plant-Based   4.5     690      -
# 5   Larabar Peanut Butter Cookie, Gluten Free Vega...   4.5   18843      -
# 6   Orgain Organic Plant Based Protein Bar, Peanut...   4.2    5823      -
# 7   Orgain Organic Vegan Plant Based Nutritional S...   4.4    9360  37.00
# 8   Vana Life's Foods Plant based Ready Meal - Gre...   4.6      39      -
# 9   Wellness CORE Bowl Boosters, Functional Meal T...   4.5     775      -
# 10  Plant Based Cookbook For Beginners: 1000 Days ...   4.4     238  13.99
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="Amazon", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='Amazon(1).csv')])
# Out:
# {'sucess': True,
#  'file_id': 865,
#  'path': 'thanaporn/DSI310-G3/processData/Amazon.parquet',
#  'lineage': True}
